# %%
from cognite.neat import NeatSession, get_cognite_client
import cognite.neat.plugins as _plugin

client = get_cognite_client(".env")
neat = NeatSession(client)
# Out:
# Found .env file in repository root. Loaded variables from .env file.
# For Neat to improve, we need to collect usage information. You acknowledge and agree that neat may collect usage information.To remove this message run 'neat.opt.in_() or to stop collecting usage information run 'neat.opt.out()'.

# %%
# Read and process the CFIHOS containers model
neat.plugins.data_model.read("cfihos",model_type="containers", configurationDir="configuration/config.yaml")
# Out:
# You are using an external plugin CFIHOS_2DataModelImporter, which is not developed by the NEAT team.
# Use it at your own risk.
# 2025-11-06 22:07:43,552 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 103 Starting model processing...
# 2025-11-06 22:07:43,552 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 106 Step 1: Setting up model processors...
# 2025-11-06 22:07:43,552 cfihos_handler.framework.processing.processors.sparse_properties INFO     MainProcess 1039 [Model Processor] Setting up STANDARD-CFIHOS
# 2025-11-06 22:07:44,359 cfihos_handler.framework.processing.processors.sparse_properties INFO     MainProcess 1039 [Model Processor] Setting up XOM-CFIHOS
# 2025-11-06 22:07:44,364 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 110 Step 2: Collecting data from processors...
# 2025-11-06 22:07:44,364 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting entity
# 2025-11-06 22:07:44,428 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Appending 1 reverse direct relation properties
# 2025-11-06 22:07:44,430 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting equipment
# 2025-11-06 22:07:44,449 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000012
# 2025-11-06 22:07:44,450 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000036
# 2025-11-06 22:07:44,450 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000046
# 2025-11-06 22:07:44,451 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000081
# 2025-11-06 22:07:44,451 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000100
# 2025-11-06 22:07:44,451 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000108
# 2025-11-06 22:07:44,452 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000133
# 2025-11-06 22:07:44,452 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000135
# 2025-11-06 22:07:44,452 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000138
# 2025-11-06 22:07:44,453 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000139
# 2025-11-06 22:07:44,453 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000164
# 2025-11-06 22:07:44,453 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000165
# 2025-11-06 22:07:44,453 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000170
# 2025-11-06 22:07:44,453 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000171
# 2025-11-06 22:07:44,454 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000184
# 2025-11-06 22:07:44,454 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000189
# 2025-11-06 22:07:44,454 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000191
# 2025-11-06 22:07:44,454 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000203
# 2025-11-06 22:07:44,455 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000205
# 2025-11-06 22:07:44,455 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000221
# 2025-11-06 22:07:44,455 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000225
# 2025-11-06 22:07:44,455 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000235
# 2025-11-06 22:07:44,456 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000257
# 2025-11-06 22:07:44,456 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000274
# 2025-11-06 22:07:44,457 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000275
# 2025-11-06 22:07:44,457 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000290
# 2025-11-06 22:07:44,457 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name '' is None, for ECFIHOS-30000311
# 2025-11-06 22:07:44,458 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000324
# 2025-11-06 22:07:44,458 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000371
# 2025-11-06 22:07:44,459 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000397
# 2025-11-06 22:07:44,459 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000402
# 2025-11-06 22:07:44,460 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000435
# 2025-11-06 22:07:44,460 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000436
# 2025-11-06 22:07:44,460 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000456
# 2025-11-06 22:07:44,461 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000471
# 2025-11-06 22:07:44,461 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000481
# 2025-11-06 22:07:44,461 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000488
# 2025-11-06 22:07:44,463 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000608
# 2025-11-06 22:07:44,463 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000613
# 2025-11-06 22:07:44,463 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000618
# 2025-11-06 22:07:44,464 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000626
# 2025-11-06 22:07:44,464 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000627
# 2025-11-06 22:07:44,464 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000658
# 2025-11-06 22:07:44,465 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000659
# 2025-11-06 22:07:44,467 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000878
# 2025-11-06 22:07:44,467 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000903
# 2025-11-06 22:07:44,468 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000951
# 2025-11-06 22:07:44,468 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000961
# 2025-11-06 22:07:44,469 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30001006
# 2025-11-06 22:07:44,947 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting tag
# 2025-11-06 22:07:44,965 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000012
# 2025-11-06 22:07:44,965 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000036
# 2025-11-06 22:07:44,965 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000046
# 2025-11-06 22:07:44,966 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000081
# 2025-11-06 22:07:44,966 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000100
# 2025-11-06 22:07:44,967 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000108
# 2025-11-06 22:07:44,967 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000133
# 2025-11-06 22:07:44,967 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000135
# 2025-11-06 22:07:44,968 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000138
# 2025-11-06 22:07:44,968 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000139
# 2025-11-06 22:07:44,968 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000164
# 2025-11-06 22:07:44,968 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000165
# 2025-11-06 22:07:44,969 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000170
# 2025-11-06 22:07:44,969 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000171
# 2025-11-06 22:07:44,969 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000184
# 2025-11-06 22:07:44,970 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000189
# 2025-11-06 22:07:44,970 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000191
# 2025-11-06 22:07:44,970 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000203
# 2025-11-06 22:07:44,970 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000205
# 2025-11-06 22:07:44,970 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000221
# 2025-11-06 22:07:44,971 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000225
# 2025-11-06 22:07:44,971 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000235
# 2025-11-06 22:07:44,972 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000257
# 2025-11-06 22:07:44,972 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000274
# 2025-11-06 22:07:44,972 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000275
# 2025-11-06 22:07:44,972 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000290
# 2025-11-06 22:07:44,973 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name '' is None, for TCFIHOS-30000311
# 2025-11-06 22:07:44,973 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000324
# 2025-11-06 22:07:44,974 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000371
# 2025-11-06 22:07:44,974 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000397
# 2025-11-06 22:07:44,975 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000402
# 2025-11-06 22:07:44,975 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000435
# 2025-11-06 22:07:44,975 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000436
# 2025-11-06 22:07:44,976 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000456
# 2025-11-06 22:07:44,976 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000471
# 2025-11-06 22:07:44,976 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000481
# 2025-11-06 22:07:44,977 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000488
# 2025-11-06 22:07:44,978 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000608
# 2025-11-06 22:07:44,979 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000613
# 2025-11-06 22:07:44,979 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000618
# 2025-11-06 22:07:44,980 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000626
# 2025-11-06 22:07:44,980 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000627
# 2025-11-06 22:07:44,980 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000647
# 2025-11-06 22:07:44,981 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000658
# 2025-11-06 22:07:44,981 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000659
# 2025-11-06 22:07:44,983 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000878
# 2025-11-06 22:07:44,983 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000903
# 2025-11-06 22:07:44,984 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000951
# 2025-11-06 22:07:44,984 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000961
# 2025-11-06 22:07:44,985 cfihos_handler.framework.importer.base_model_interpreter WARNING  MainProcess 81 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30001006
# 2025-11-06 22:07:45,102 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting entity
# 2025-11-06 22:07:45,112 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting equipment
# 2025-11-06 22:07:45,119 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting tag
# 2025-11-06 22:07:45,131 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 114 Step 3: Validating collected data...
# 2025-11-06 22:07:45,133 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 118 Step 4: Processing and transforming data...
# 2025-11-06 22:07:45,143 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 122 Step 5: Building final model structures...
# 2025-11-06 22:07:46,553 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 125 Model processing completed successfully
# 2025-11-06 22:07:46,554 cfihos_handler.framework.processing.model_managers.sparse_model_manager INFO     MainProcess 126 Buidling 0 container properties ...
# 2025-11-06 22:07:46,556 cfihos_handler.framework.processing.model_managers.sparse_model_manager INFO     MainProcess 141 Generating NEAT Data Model ...
# [WARNING] Experimental feature 'plugin' is subject to change without notice
# [DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='document_number_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='project_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='reason_for_issue_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='tag_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='from_plant_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='from_tag_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='to_plant_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='to_tag_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='imperial_unit_of_measure_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='si_unit_of_measure_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='manufacturer_company_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='model_part_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='iso_currency_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='purchase_order_issuer_company_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='purchase_order_number_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='discipline_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='engineering_status_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='data_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='document_revision_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='process_unit_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='asset_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='documentation_representation_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='parent_construction_assembly_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='parent_commissioning_unit_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000101_10000201_ext', version='1'), prop_name='cfihos_unique_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='unit_of_measure_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='unit_of_measure_dimension_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='measurement_system_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='sending_company_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='tag_or_equipment_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='application_condition_group_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='application_condition_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='parent_tag_or_equipment_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='event_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='source_standard_document_and_data_requirement_number_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='default_for_information_reference_date_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='default_issue_for_approval_reference_date_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='default_issue_for_review_reference_date_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='default_required_handover_status_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='document_and_data_requirement_group_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='document_and_data_requirement_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='purchase_order_item_number_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='document_type_classification_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='referenced_document_number_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='referenced_document_revision_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='coding_source_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000201_10000301_ext', version='1'), prop_name='comparison_operator_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='plant_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='property_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='source_standard_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='tag_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='equipment_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='document_type_short_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='property_picklist_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='property_picklist_value_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='maintenance_unit_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='commissioning_unit_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='site_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='equipment_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='area_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='document_status_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='document_review_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000001_10000101_ext', version='1'), prop_name='corrosion_loop_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='process_activity_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='process_stream_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='component_role_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='property_group_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='stream_class_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='parent_stream_class_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='original_model_part_manufacturer_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='original_model_part_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='spir_reference_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='deliverable_format_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='property_grouping_purpose_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='parent_group_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='process_case_number_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='input_of_process_activity_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='output_of_process_activity_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='process_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='parent_process_activity_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='handover_event_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='authenticated_record_format_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='native_document_format_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000301_10000401_ext', version='1'), prop_name='native_file_delivery_timing_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000401_10000501_ext', version='1'), prop_name='spir_model_part_type_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000401_10000501_ext', version='1'), prop_name='kit_manufacturer_company_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_1_10000401_10000501_ext', version='1'), prop_name='kit_model_part_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='commissioning_unit_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='construction_assembly_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='corrosion_loop_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='maintenance_system_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='maintenance_unit_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='safety_critical_item_group_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='tag_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000028', version='1'), prop_name='tag_status_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000105', version='1'), prop_name='unit_of_measure_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000036', version='1'), prop_name='project_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000031', version='1'), prop_name='industrial_complex_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000031', version='1'), prop_name='iso_language_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000008', version='1'), prop_name='equipment_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000008', version='1'), prop_name='model_part_type_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000008', version='1'), prop_name='unit_of_measure_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000012', version='1'), prop_name='equipment_class_name_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000012', version='1'), prop_name='iso_currency_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='document_return_status_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='document_status_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='export_control_classification_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='iso_language_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='project_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='project_stage_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='storage_media_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000035', version='1'), prop_name='transmittal_number_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000022', version='1'), prop_name='discipline_document_type_short_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000022', version='1'), prop_name='document_review_type_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000009', version='1'), prop_name='iso_country_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000023', version='1'), prop_name='iso_language_code_rel'),
#  DirectRelationMissingSourceWarning(view_id=ViewId(space='sp_example_dev_cfihos_containers', external_id='CFIHOS_00000023', version='1'), prop_name='storage_media_code_rel')]

# %%
# example to read the dry run result for further investigation
deploy_result = neat.to.cdf.data_model(existing="force", dry_run=True)

# %%
# display the dry run result
deploy_result

# %%
# deploy model to CDF, breaking changes will not pass
neat.to.cdf.data_model()

# %%
# deploy model to CDF forcing breaking changes. NOTE: this will delete all data in impacted containers.
neat.to.cdf.data_model(existing="force", dry_run=False,drop_data=True)
