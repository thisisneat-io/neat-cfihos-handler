# %%
import cognite.neat.plugins as _plugin
from cognite.neat import NeatSession, get_cognite_client

client = get_cognite_client(".env")
neat_views = NeatSession(client)
# Out:
# Found .env file in repository root. Loaded variables from .env file.
# For Neat to improve, we need to collect usage information. You acknowledge and agree that neat may collect usage information.To remove this message run 'neat.opt.in_() or to stop collecting usage information run 'neat.opt.out()'.

# %%
#NOTE: Always make sure the container data model is deployed to CDF before deploying the views data model
# Read and process the CFIHOS views model
neat_views.plugins.data_model.read(
    "cfihos",
    model_type="views",
    scope="Example Centrifugal Pump",
    configurationDir="configuration/config.yaml",
)
# Out:
# You are using an external plugin CFIHOS_2DataModelImporter, which is not developed by the NEAT team.
# Use it at your own risk.
# 2025-11-04 13:08:25,607 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 103 Starting model processing...
# 2025-11-04 13:08:25,607 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 106 Step 1: Setting up model processors...
# 2025-11-04 13:08:25,608 cfihos_handler.framework.processing.processors.sparse_properties INFO     MainProcess 1039 [Model Processor] Setting up STANDARD-CFIHOS
# 2025-11-04 13:08:26,358 cfihos_handler.framework.processing.processors.sparse_properties INFO     MainProcess 1039 [Model Processor] Setting up XOM-CFIHOS
# 2025-11-04 13:08:26,360 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in src/xom 2.0/XOM CORE RDL master object v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:26,362 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in src/xom 2.0/XOM CORE RDL master object v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:26,364 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 110 Step 2: Collecting data from processors...
# 2025-11-04 13:08:26,364 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting entity
# 2025-11-04 13:08:26,382 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/2.0/CFIHOS CORE data dictionary v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:26,431 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Appending 1 reverse direct relation properties
# 2025-11-04 13:08:26,433 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting equipment
# 2025-11-04 13:08:26,465 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/2.0/CFIHOS CORE equipment class v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:26,472 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000012
# 2025-11-04 13:08:26,472 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000036
# 2025-11-04 13:08:26,473 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000046
# 2025-11-04 13:08:26,473 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000081
# 2025-11-04 13:08:26,474 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000100
# 2025-11-04 13:08:26,474 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000108
# 2025-11-04 13:08:26,475 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000133
# 2025-11-04 13:08:26,475 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000135
# 2025-11-04 13:08:26,475 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000138
# 2025-11-04 13:08:26,475 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000139
# 2025-11-04 13:08:26,476 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000164
# 2025-11-04 13:08:26,476 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000165
# 2025-11-04 13:08:26,476 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000170
# 2025-11-04 13:08:26,476 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000171
# 2025-11-04 13:08:26,477 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000184
# 2025-11-04 13:08:26,478 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000189
# 2025-11-04 13:08:26,478 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000191
# 2025-11-04 13:08:26,480 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000203
# 2025-11-04 13:08:26,481 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000205
# 2025-11-04 13:08:26,481 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000221
# 2025-11-04 13:08:26,484 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30000225
# 2025-11-04 13:08:26,485 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for ECFIHOS-30
cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000435
# 2025-11-04 13:08:27,034 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000436
# 2025-11-04 13:08:27,034 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000456
# 2025-11-04 13:08:27,034 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000471
# 2025-11-04 13:08:27,035 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000481
# 2025-11-04 13:08:27,035 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000488
# 2025-11-04 13:08:27,036 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000608
# 2025-11-04 13:08:27,037 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000613
# 2025-11-04 13:08:27,037 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000618
# 2025-11-04 13:08:27,037 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000626
# 2025-11-04 13:08:27,038 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000627
# 2025-11-04 13:08:27,038 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000647
# 2025-11-04 13:08:27,038 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000658
# 2025-11-04 13:08:27,039 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000659
# 2025-11-04 13:08:27,041 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000878
# 2025-11-04 13:08:27,042 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000903
# 2025-11-04 13:08:27,042 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000951
# 2025-11-04 13:08:27,043 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30000961
# 2025-11-04 13:08:27,043 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] parent name 'IT and telecom equipment' is None, for TCFIHOS-30001006
# 2025-11-04 13:08:27,074 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/2.0/CFIHOS CORE tag class property v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,096 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/2.0/CFIHOS CORE property v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,161 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting entity
# 2025-11-04 13:08:27,162 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CORE data dictionary v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,164 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CDF core data model.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,169 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM Edges.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,178 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting equipment
# 2025-11-04 13:08:27,180 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CORE equipment class v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,192 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CORE equipment class property v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,196 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CORE property v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,202 cfihos_handler.framework.importer.base_model_interpreter INFO     MainProcess 76 [CfihosModelLoader:CFIHOS] Collecting tag
# 2025-11-04 13:08:27,203 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CORE tag class v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,209 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CORE tag class property v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,213 cfihos_handler.framework.common.utils WARNING  MainProcess 78 ⚠️ Low confidence or ascii in ./src/xom 2.0/XOM CORE property v2.0.csv — falling back to 'cp1252'
# 2025-11-04 13:08:27,224 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 114 Step 3: Validating collected data...
# 2025-11-04 13:08:27,225 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 118 Step 4: Processing and transforming data...
# 2025-11-04 13:08:27,235 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 122 Step 5: Building final model structures...
# 2025-11-04 13:08:28,927 cfihos_handler.framework.processing.processors.base_processor INFO     MainProcess 125 Model processing completed successfully
# 2025-11-04 13:08:28,927 cfihos_handler.framework.processing.model_managers.sparse_model_manager INFO     MainProcess 167 Building model for scope 'Example Centrifugal Pump' ...
# 2025-11-04 13:08:28,928 cfihos_handler.framework.common.utils INFO     MainProcess 314 Selected 53 objects from 1823
# 2025-11-04 13:08:28,928 cfihos_handler.framework.processing.model_managers.sparse_model_manager INFO     MainProcess 176 Building scoped query model views ...
# 2025-11-04 13:08:28,929 cfihos_handler.framework.processing.model_managers.sparse_model_manager INFO     MainProcess 184 Building 53 scoped entity views
# [WARNING] Experimental feature 'plugin' is subject to change without notice
# [NeatValueError(raw_message="Scope 'Example Centrifugal Pump' is missing required keys: scope_model_version")]

# %%
# deploy neat session to CDF
neat_views.to.cdf.data_model()
# Out:
# You can inspect the details with the .inspect.outcome.data_model(...) method.
# [UploadResult(name='spaces', error_messages=[], issues=[], created={'sp_example_dev_cfihos_views'}, upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set(), failed_items=[]),
#  UploadResult(name='containers', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set(), failed_items=[]),
#  UploadResult(name='views', error_messages=[], issues=[], created={ViewId(space='sp_example_dev_cfihos_views', external_id='DisciplineDocumentType', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Site', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='IsoCountry', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='IndustrialComplex', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='ProcessUnit', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='ModelPart', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='PurchaseOrder', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='TagOrEquipmentClass', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='CommissioningUnit', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='CorrosionLoop', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Area', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='ModelPartType', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='LeafNodeCommissioningUnit', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentTypeClassification', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='CentrifugalPump_T', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentStatus', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentFormat', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Equipment', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentType', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='MaintenanceSystem', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='CustomSiteEntity', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='MechanicalEquipmentClass_T', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentReviewType', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Tag', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='ConstructionAssembly', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='IsoLanguage', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentRepresentationType', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='UnitOfMeasure', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='CustomEntity4', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='AdditionalFile', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='ProjectStage', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Pump_T', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='MeasurementSystem', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='NativeFileDeliveryTiming', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentRevision', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Company', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Discipline', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='DocumentRevisionSiteReference', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Project', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='MaintenanceUnit', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='UnitOfMeasureDimension', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='IsoCurrency', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='StorageMedia', version='1'), ViewId(space='sp_example_dev_cfihos_views', external_id='Transmittal', version='1'), ViewId(space='sp_example_dev_cfi ...
#  UploadResult(name='data_models', error_messages=[], issues=[], created={DataModelId(space='sp_example_dev_cfihos_views', external_id='CFIHOS_EXAMPLE_CENTRIFUGAL_PUMP', version='1')}, upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set(), failed_items=[]),
#  UploadResult(name='nodes', error_messages=[], issues=[], created=set(), upserted=set(), deleted=set(), changed=set(), unchanged=set(), skipped=set(), failed_created=set(), failed_upserted=set(), failed_changed=set(), failed_deleted=set(), failed_items=[])]

# %%
neat_views.inspect.issues()
# Out:
# ### 1 issues found
#
#   * **NeatValueError**: Scope 'Example Centrifugal Pump' is missing required keys: scope_model_version
